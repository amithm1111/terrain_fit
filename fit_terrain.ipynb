# %%
""" same p1-p4 for all the patches """
# Out:
# ' same p1-p4 for all the patches '

# %%
import os
import numpy as np
import open3d as o3d
import matplotlib.pyplot as plt
import matplotlib.cm as mpl
from scipy.interpolate import griddata

import time
import jax
import jax.numpy as jnp
from jax import grad, jit, vmap
from functools import partial
from jax import random
import jaxopt
from jaxopt import GaussNewton
# Out:
# Jupyter environment detected. Enabling Open3D WebVisualizer.
# [Open3D INFO] WebRTC GUI backend enabled.
# [Open3D INFO] WebRTCWindowSystem: HTTP handshake server disabled.

# %%
class fft_fit():

    def __init__(self):

        self.gn = GaussNewton(residual_fun=self.error_fn,maxiter=10,verbose=False,implicit_diff=True,jit=True )
        

    @partial(jit, static_argnums = (0,))
    def get_kernel(self, xy, p1, p2, p3, p4, lambdas):
        """
        Creates a fft kernel from the local point cloud patch
        """
        c_term = jnp.vstack((p1, p2))
        s_term = jnp.vstack((p3, p4))
        kernel = jnp.hstack((jnp.cos(xy@c_term), jnp.sin(xy@s_term)))
        
        pred_z = (kernel@lambdas)[:,0]

        return pred_z

    @partial(jit, static_argnums = (0,))
    def solve(self,lam,p1,p2,p3,p4,pcd):
        lamdas, state = self.gn.run(lam,p1,p2,p3,p4,pcd)
        return lamdas
    
    @partial(jit, static_argnums = (0,))
    def error_fn(self, lambdas, p1, p2, p3, p4, pcd):  
        lambdas = lambdas.reshape(-1,1)
        xy = pcd[:, :2]
        gt_z = pcd[:, -1]
        pred_z = self.get_kernel(xy, p1, p2, p3, p4, lambdas)
        error = jnp.hstack((pred_z - gt_z, 0.15*lambdas.squeeze(axis=-1)))

        return error

# %%
data_dir = "./src/terrain_mlp/fft_new/data/concatenated-cloud/run-0"

# total number of .npz files
end_frame = len([name for name in os.listdir(data_dir) if os.path.isfile(os.path.join(data_dir, name)) and name.endswith(".npz")])
print("total samples: ", end_frame)

# .npz files named primitives-data-0 to primitives-data-{end_frame}
trainingfile_names = [f"data{i}.npz" for i in range(1, end_frame)]
trainingfile_paths = [os.path.join(data_dir, file) for file in trainingfile_names]
# Out:
# total samples:  466

# %%
pcd_data = []
N = 35000
# i = 0
for file_path in trainingfile_paths:
    data = np.load(file_path)      
    cloud = data['cloud']
    pc = o3d.geometry.PointCloud()
    pc.points = o3d.utility.Vector3dVector(cloud)
    pc = pc.voxel_down_sample(voxel_size=0.06)
    pcd = np.asarray(pc.points, dtype=np.float32)
    if pcd.shape[0]>35000:
        indices = np.random.choice(len(pcd), N, replace=False)
        sampled_pcd = pcd[indices]
        # spc = o3d.geometry.PointCloud()
        # spc.points = o3d.utility.Vector3dVector(sampled_pcd)
        # o3d.visualization.draw_geometries([spc])
        pcd_data.append(sampled_pcd)

    # if i>25:
    #     break
    # i += 1
        
pcd_array = np.array(pcd_data)
print(pcd_array.shape)

xyz = np.nan_to_num(pcd_array,posinf=0.0,neginf=0.0)

# batch_size = xyz.shape[0]
# patch_size = xyz.shape[1]
# pcd_shift = np.zeros((batch_size,patch_size,3))
# temp = np.min(xyz[:, :, :2], axis=1)
# pcd_shift[:,:,0] = xyz[:,:,0]-np.expand_dims(temp[:,0], axis=-1)
# pcd_shift[:,:,1] = xyz[:,:,1]-np.expand_dims(temp[:,1], axis=-1)
# pcd_shift[:,:,2] = xyz[:,:,2]

pcd_shift = xyz
# Out:
# (185, 35000, 3)

# %%
# fig, ax = plt.subplots()
# plt.rcParams["font.weight"] = "bold"
# ax.set_xlabel('x (m)')
# ax.set_ylabel('y (m)')
# ax.scatter(pcd_shift[10,:,0],pcd_shift[10,:,1])
# plt.show()

# print(pcd_shift[0,:,0].min())
# print(pcd_shift[0,:,1].min())

# %%
pcd_jax = jnp.asarray(pcd_shift)
num_lamdas = 200
num_params = 100

lam_data = jnp.zeros((pcd_jax.shape[0],num_lamdas))

key1 = jax.random.PRNGKey(0)
key2 = jax.random.PRNGKey(1)
key3 = jax.random.PRNGKey(2)
key4 = jax.random.PRNGKey(3)
key5 = jax.random.PRNGKey(4)

#aux_vars
p1 = random.normal(key1, shape=(num_params,), dtype=jnp.float32)
p2 = random.normal(key2, shape=(num_params,), dtype=jnp.float32)
p3 = random.normal(key3, shape=(num_params,), dtype=jnp.float32)
p4 = random.normal(key4, shape=(num_params,), dtype=jnp.float32)

fft_obj = fft_fit()

for s in range(pcd_jax.shape[0]):

    key5,subkey5 = jax.random.split(key5)

    # opt_vars
    lam = random.normal(key5, shape=(num_lamdas,), dtype=jnp.float32)

    t1 = time.time()
    lamdas = fft_obj.solve(lam,p1,p2,p3,p4,pcd_jax[s,:,:])
    t2 = time.time()
    print("case = ", s, "Time to construct FFT = ", t2-t1)

    z_new = fft_obj.get_kernel(pcd_jax[s,:,0:2], p1, p2, p3, p4, lamdas.reshape(-1,1))
    z_new = jnp.clip(z_new,-6.0,6.0)

    error = z_new - pcd_jax[s,:,2]
    print("error", jnp.linalg.norm(error))

    lam_data = lam_data.at[s,:].set(lamdas)
# Out:
# case =  0 Time to construct FFT =  1.7108113765716553
# error 7.561141
# case =  1 Time to construct FFT =  1.124314308166504
# error 7.541844
# case =  2 Time to construct FFT =  1.1340575218200684
# error 7.5473533
# case =  3 Time to construct FFT =  1.1400468349456787
# error 7.5563173
# case =  4 Time to construct FFT =  1.1503703594207764
# error 7.803787
# case =  5 Time to construct FFT =  1.1491847038269043
# error 19.975752
# case =  6 Time to construct FFT =  1.1524317264556885
# error 7.1939597
# case =  7 Time to construct FFT =  1.140822410583496
# error 18.183222
# case =  8 Time to construct FFT =  1.139664888381958
# error 8.260234
# case =  9 Time to construct FFT =  1.1514763832092285
# error 8.62023
# case =  10 Time to construct FFT =  1.1397755146026611
# error 9.192831
# case =  11 Time to construct FFT =  1.1356730461120605
# error 10.8666
# case =  12 Time to construct FFT =  1.1367783546447754
# error 10.297227
# case =  13 Time to construct FFT =  1.146758794784546
# error 8.392444
# case =  14 Time to construct FFT =  1.1355435848236084
# error 9.115426
# case =  15 Time to construct FFT =  1.1597340106964111
# error 9.205851
# case =  16 Time to construct FFT =  1.1285521984100342
# error 9.8412
# case =  17 Time to construct FFT =  1.1118624210357666
# error 9.878903
# case =  18 Time to construct FFT =  1.1436970233917236
# error 9.880305
# case =  19 Time to construct FFT =  1.117964744567871
# error 8.456223
# case =  20 Time to construct FFT =  1.0904943943023682
# error 16.900574
# case =  21 Time to construct FFT =  1.0636372566223145
# error 18.709383
# case =  22 Time to construct FFT =  1.054908037185669
# error 8.9484215
# case =  23 Time to construct FFT =  1.0447776317596436
# error 16.59962
# case =  24 Time to construct FFT =  1.0488595962524414
# error 10.8543
# case =  25 Time to construct FFT =  1.0496833324432373
# error 23.94977
# case =  26 Time to construct FFT =  1.0394256114959717
# error 10.864871
# case =  27 Time to construct FFT =  1.0436129570007324
# error 13.82424
# case =  28 Time to construct FFT =  1.0538196563720703
# error 12.209763
# case =  29 Time to construct FFT =  1.0472846031188965
# error 11.096396
# case =  30 Time to construct FFT =  1.062408685684204
# error 48.173847
# case =  31 Time to construct FFT =  1.0578608512878418
# error 8.236759
# case =  32 Time to construct FFT =  1.0982873439788818
# error 8.661332
# case =  33 Time to construct FFT =  1.0497345924377441
# error 16.38143
# case =  34 Time to construct FFT =  1.0542707443237305
# error 7.602023
# case =  35 Time to construct FFT =  1.0494105815887451
# error 8.246745
# case =  36 Time to construct FFT =  1.058941125869751
# error 8.211584
# case =  37 Time to construct FFT =  1.043318510055542
# error 7.522138
# case =  38 Time to construct FFT =  1.0786566734313965
# error 11.003645
# case =  39 Time to construct FFT =  1.0501067638397217
# error 9.909063
# case =  40 Time to construct FFT =  1.0462968349456787
# error 51.739464
# case =  41 Time to construct FFT =  1.0580358505249023
# error 21.435328
# case =  42 Time to construct FFT =  1.0430049896240234
# error 7.764063
# case =  43 Time to construct FFT =  1.0607140064239502
# error 7.7693663
# case =  44 Time to construct FFT =  1.0607764720916748
# error 22.06702
# case =  45 Time to construct FFT =  1.0519726276397705
# error 6.9725914
# case =  46 Time to construct FFT =  1.059891939163208
# error 16.53508
# case =  47 Time to construct FFT =  1.0502057075500488
# error 7.6437554
# case =  48 Time to construct FFT =  1.044245958328247
# error 7.4612937
# case =  49 Time to construct FFT =  1.0468649864196777
# error 12.963333
# case =  50 Time to construct FFT =  1.0618095397949219
# error 27.957483
# case =  51 Time to construct FFT =  1.051018238067627
# error 14.035553
# case =  52 Time to construct FFT =  1.058225154876709
# error 7.810037
# case =  53 Time to construct FFT =  1.0803730487823486
# error 8.574063
# case =  54 Time to construct FFT =  1.1332190036773682
# error 8.13606
# case =  55 Time to construct FFT =  1.134962558746338
# error 11.695335
# case =  56 Time to construct FFT =  1.1461527347564697
# error 7.6407294
# case =  57 Time to construct FFT =  1.149707317352295
# error 8.2909975
# case =  58 Time to construct FFT =  1.139585256576538
# error 9.299359
# case =  59 Time to construct FFT =  1.1641006469726562
# error 21.863976
# case =  60 Time to construct FFT =  1.1418156623840332
# error 12.112366
# case =  61 Time to construct FFT =  1.1573984622955322
# error 16.621702
# case =  62 Time to construct FFT =  1.1660830974578857
# error 12.599949
# case =  63 Time to construct FFT =  1.1522936820983887
# error 20.607622
# case =  64 Time to construct FFT =  1.1582176685333252
# error 7.8143873
# case =  65 Time to construct FFT =  1.0887393951416016
# error 7.448483
# case =  66 Time to construct FFT =  1.0855841636657715
# error 23.455502
# case =  67 Time to construct FFT =  1.0842037200927734
# error 12.754492
# case =  68 Time to construct FFT =  1.0982246398925781
# error 8.138958
# case =  69 Time to construct FFT =  1.0934698581695557
# error 6.9042206
# case =  70 Time to construct FFT =  1.090132474899292
# error 9.231984
# case =  71 Time to construct FFT =  1.1123230457305908
# error 7.794133
# case =  72 Time to construct FFT =  1.0990900993347168
# error 8.253355
# case =  73 Time to construct FFT =  1.0996339321136475
# error 9.677361
# case =  74 Time to construct FFT =  1.0928869247436523
# error 7.726941
# case =  75 Time to construct FFT =  1.0876641273498535
# error 11.284522
# case =  76 Time to construct FFT =  1.1021766662597656
# error 13.878914
# case =  77 Time to construct FFT =  1.0870964527130127
# error 11.029206
# case =  78 Time to construct FFT =  1.102381944656372
# error 21.829557
# case =  79 Time to construct FFT =  1.104762077331543
# error 13.52511
# case =  80 Time to construct FFT =  1.1009976863861084
# error 48.928226
# case =  81 Time to construct FFT =  1.1040198802947998
# error 25.843767
# case =  82 Time to construct FFT =  1.0934276580810547
# error 44.876385
# case =  83 Time to construct FFT =  1.0875110626220703
# error 9.46884
# case =  84 Time to construct FFT =  1.088637351989746
# error 24.912483
# case =  85 Time to construct FFT =  1.0945191383361816
# error 11.393775
# case =  86 Time to construct FFT =  1.1173861026763916
# error 13.175197
# case =  87 Time to construct FFT =  1.1172840595245361
# error 8.886888
# case =  88 Time to construct FFT =  1.1161384582519531
# error 10.339208
# case =  89 Time to construct FFT =  1.1114163398742676
# error 42.233707
# case =  90 Time to construct FFT =  1.1053719520568848
# error 20.52616
# case =  91 Time to construct FFT =  1.1067428588867188
# error 6.7957735
# case =  92 Time to construct FFT =  1.0991394519805908
# error 11.716794
# case =  93 Time to construct FFT =  1.0963892936706543
# error 11.483504
# case =  94 Time to construct FFT =  1.0967378616333008
# error 21.931135
# case =  95 Time to construct FFT =  1.0801255702972412
# error 12.039476
# case =  96 Time to construct FFT =  1.093893051147461
# error 10.497382
# case =  97 Time to construct FFT =  1.0885300636291504
# error 7.901604
# case =  98 Time to construct FFT =  1.1034438610076904
# error 8.434716
# case =  99 Time to construct FFT =  1.1127538681030273
# error 22.220192
# case =  100 Time to construct FFT =  1.0928642749786377
# error 7.114444
# case =  101 Time to construct FFT =  1.0915865898132324
# error 23.72453
# case =  102 Time to construct FFT =  1.0973083972930908
# error 23.539787
# case =  103 Time to construct FFT =  1.1089134216308594
# error 22.979496
# case =  104 Time to construct FFT =  1.0838522911071777
# error 15.677207
# case =  105 Time to construct FFT =  1.0983495712280273
# error 10.858601
# case =  106 Time to construct FFT =  1.1011009216308594
# error 8.675175
# case =  107 Time to construct FFT =  1.0955474376678467
# error 37.861336
# case =  108 Time to construct FFT =  1.0863754749298096
# error 6.704176
# case =  109 Time to construct FFT =  1.1024816036224365
# error 7.8769245
# case =  110 Time to construct FFT =  1.1008925437927246
# error 16.15478
# case =  111 Time to construct FFT =  1.08073091506958
# error 8.798131
# case =  112 Time to construct FFT =  1.0888817310333252
# error 14.200481
# case =  113 Time to construct FFT =  1.084367275238037
# error 7.2986865
# case =  114 Time to construct FFT =  1.0837979316711426
# error 7.251822
# case =  115 Time to construct FFT =  1.0958027839660645
# error 7.4292226
# case =  116 Time to construct FFT =  1.0773487091064453
# error 7.361577
# case =  117 Time to construct FFT =  1.08845853805542
# error 8.0149
# case =  118 Time to construct FFT =  1.0990803241729736
# error 7.906833
# case =  119 Time to construct FFT =  1.077646017074585
# error 8.518721
# case =  120 Time to construct FFT =  1.0887188911437988
# error 8.657176
# case =  121 Time to construct FFT =  1.0904004573822021
# error 14.678898
# case =  122 Time to construct FFT =  1.0906031131744385
# error 9.397045
# case =  123 Time to construct FFT =  1.11018967628479
# error 8.724193
# case =  124 Time to construct FFT =  1.0909168720245361
# error 11.91526
# case =  125 Time to construct FFT =  1.1045656204223633
# error 23.076498
# case =  126 Time to construct FFT =  1.097076416015625
# error 8.231711
# case =  127 Time to construct FFT =  1.0938901901245117
# error 9.234427
# case =  128 Time to construct FFT =  1.1110334396362305
# error 9.982022
# case =  129 Time to construct FFT =  1.0978035926818848
# error 8.770201
# case =  130 Time to construct FFT =  1.0914759635925293
# error 7.525997
# case =  131 Time to construct FFT =  1.0910494327545166
# error 13.358101
# case =  132 Time to construct FFT =  1.0866081714630127
# error 10.689519
# case =  133 Time to construct FFT =  1.1033482551574707
# error 7.716317
# case =  134 Time to construct FFT =  1.0865752696990967
# error 38.410397
# case =  135 Time to construct FFT =  1.0967724323272705
# error 16.018148
# case =  136 Time to construct FFT =  1.0824809074401855
# error 7.8363004
# case =  137 Time to construct FFT =  1.0919435024261475
# error 18.418972
# case =  138 Time to construct FFT =  1.0961506366729736
# error 30.878038
# case =  139 Time to construct FFT =  1.1193249225616455
# error 20.416643
# case =  140 Time to construct FFT =  1.0908775329589844
# error 7.277019
# case =  141 Time to construct FFT =  1.0951945781707764
# error 9.186177
# case =  142 Time to construct FFT =  1.0934455394744873
# error 12.384394
# case =  143 Time to construct FFT =  1.0926358699798584
# error 8.497129
# case =  144 Time to construct FFT =  1.0808649063110352
# error 9.3681135
# case =  145 Time to construct FFT =  1.1063947677612305
# error 16.600336
# case =  146 Time to construct FFT =  1.1066813468933105
# error 25.869627
# case =  147 Time to construct FFT =  1.0912024974822998
# error 7.5542884
# case =  148 Time to construct FFT =  1.085038423538208
# error 7.9524164
# case =  149 Time to construct FFT =  1.089787483215332
# error 10.743052
# case =  150 Time to construct FFT =  1.094336986541748
# error 12.738438
# case =  151 Time to construct FFT =  1.1010360717773438
# error 9.317825
# case =  152 Time to construct FFT =  1.0972023010253906
# error 22.756536
# case =  153 Time to construct FFT =  1.100177526473999
# error 10.447131
# case =  154 Time to construct FFT =  1.1069941520690918
# error 12.537276
# case =  155 Time to construct FFT =  1.0986685752868652
# error 32.655304
# case =  156 Time to construct FFT =  1.080488681793213
# error 9.902668
# case =  157 Time to construct FFT =  1.0888442993164062
# error 13.035401
# case =  158 Time to construct FFT =  1.1288695335388184
# error 29.329817
# case =  159 Time to construct FFT =  1.086606740951538
# error 10.410859
# case =  160 Time to construct FFT =  1.091442346572876
# error 8.851741
# case =  161 Time to construct FFT =  1.084684133529663
# error 7.113589
# case =  162 Time to construct FFT =  1.1072006225585938
# error 7.77242
# case =  163 Time to construct FFT =  1.112330675125122
# error 8.991129
# case =  164 Time to construct FFT =  1.1147708892822266
# error 48.06517
# case =  165 Time to construct FFT =  1.1021530628204346
# error 8.432039
# case =  166 Time to construct FFT =  1.0939695835113525
# error 10.426177
# case =  167 Time to construct FFT =  1.0903329849243164
# error 18.759365
# case =  168 Time to construct FFT =  1.0968592166900635
# error 13.704899
# case =  169 Time to construct FFT =  1.1077420711517334
# error 7.333795
# case =  170 Time to construct FFT =  1.0794878005981445
# error 8.655239
# case =  171 Time to construct FFT =  1.100236177444458
# error 12.0326395
# case =  172 Time to construct FFT =  1.1034777164459229
# error 10.51328
# case =  173 Time to construct FFT =  1.08754563331604
# error 7.593483
# case =  174 Time to construct FFT =  1.0835576057434082
# error 8.279851
# case =  175 Time to construct FFT =  1.0951542854309082
# error 7.9481306
# case =  176 Time to construct FFT =  1.0866575241088867
# error 7.9383516
# case =  177 Time to construct FFT =  1.0919933319091797
# error 7.936621
# case =  178 Time to construct FFT =  1.0919342041015625
# error 8.266502
# case =  179 Time to construct FFT =  1.1095526218414307
# error 8.73482
# case =  180 Time to construct FFT =  1.101672887802124
# error 9.469697
# case =  181 Time to construct FFT =  1.0910861492156982
# error 10.578445
# case =  182 Time to construct FFT =  1.1042439937591553
# error 11.0264
# case =  183 Time to construct FFT =  1.1138479709625244
# error 8.41342
# case =  184 Time to construct FFT =  1.0990359783172607
# error 7.5548425

# %%
# cn = np.random.randint(0, 25)
# min_xy = jnp.min(pcd_jax[cn,:,:],axis=0)
# max_xy = jnp.max(pcd_jax[cn,:,:],axis=0)
# min_x = min_xy[0]
# max_x = max_xy[0]
# min_y = min_xy[1]
# max_y = max_xy[1]
# # create test data
# xs = jnp.arange(min_x,max_x,0.2, dtype=jnp.float32)
# ys = jnp.arange(min_y,max_y,0.2, dtype=jnp.float32)
# X,Y = jnp.meshgrid(xs,ys)
# xp = X.flatten()
# yp = Y.flatten()
# zp = jnp.zeros(xp.shape, dtype=jnp.float32)
# xyz_test = jnp.vstack((xp,yp,zp)).T

# z_new = fft_obj.get_kernel(xyz_test[:, :2], p1_data[cn,:], p2_data[cn,:], p3_data[cn,:], p4_data[cn,:], lam_data[cn,:].reshape(-1,1))
# z_new = jnp.clip(z_new,-6.0,6.0)

# pc_orig = pcd_jax[cn,:,:]
# pc_new = xyz_test

# pc_new = pc_new.at[:,-1].set(z_new)
# gt_pc = o3d.geometry.PointCloud()
# gt_pc.points = o3d.utility.Vector3dVector(pc_orig)
# t_pc = o3d.geometry.PointCloud()
# t_pc.points = o3d.utility.Vector3dVector(pc_new)
# gt_pc.paint_uniform_color([1, 0, 0])
# t_pc.paint_uniform_color([0, 1, 0])
# o3d.visualization.draw_geometries([gt_pc, t_pc])

# %%
# lam_data = np.asarray(lam_data)
# p1_data = np.asarray(p1)
# p2_data = np.asarray(p2)
# p3_data = np.asarray(p3)
# p4_data = np.asarray(p4)

# np.savez("./src/terrain_mlp/fft_new/data/pcd_fit_data_new",pcd=pcd_shift,lam_data=lam_data,p1_data=p1_data,p2_data=p2_data,p3_data=p3_data,p4_data=p4_data)
